# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn import preprocessing,metrics 
from IPython.core.display import HTML
pd.set_option("display.max_columns",75)
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import linear_model,svm
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve

# %%
df2012_13 = pd.read_csv('../2.1.Credit_Scoring/LoanStats2012-13.csv',skiprows=1)
df2014 = pd.read_csv('../2.1.Credit_Scoring/LoanStats2014.csv',skiprows=1)

# %%
df2012_13.head(2)
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    12000.0      12000.0          12000.0   36 months
# 1  NaN        NaN    28000.0      28000.0          28000.0   36 months
#
#   int_rate  installment grade sub_grade                     emp_title  \
# 0    6.62%       368.45     A        A2  MANAGER INFORMATION DELIVERY
# 1    7.62%       872.52     A        A3            Area Sales Manager
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0  10+ years       MORTGAGE    105000.0        Not Verified  Dec-2013
# 1    5 years       MORTGAGE    325000.0     Source Verified  Dec-2013
#
#   loan_status pymnt_plan  url desc             purpose  \
# 0  Fully Paid          n  NaN  NaN  debt_consolidation
# 1  Fully Paid          n  NaN  NaN  debt_consolidation
#
#                             title zip_code addr_state    dti  delinq_2yrs  \
# 0                  UNIVERSAL CARD    060xx         CT  14.05          0.0
# 1  Pay off other Installment loan    945xx         CA  18.55          0.0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0         Mar-1994             1.0                    43.0
# 1         Nov-1994             1.0                     NaN
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN      12.0      0.0    13168.0      21.6%       22.0
# 1                     NaN      15.0      0.0    29581.0      54.6%       31.0
#
#   initial_list_status  out_prncp       ...         total_bal_ex_mort  \
# 0                   w        0.0       ...                   42603.0
# 1                   w        0.0       ...                  199739.0
#
#    total_bc_limit  total_il_high_credit_limit  revol_bal_joint  \
# 0         52600.0                     42769.0              NaN
# 1         42200.0                    196686.0              NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                       NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
#
#    sec_app_open_acc sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                NaN                  NaN
# 1               NaN                NaN                  NaN
#
#   sec_app_num_rev_accts sec_app_chargeoff_within_12_mths  \
# 0                   NaN                              NaN
# 1                   NaN                              NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
#
#    hardship_flag hardship_type  hardship_reason  hardship_status  \
# 0              N           NaN              NaN              NaN
# 1              N           NaN              NaN              NaN
#
#    deferral_term  hardship_amount  hardship_start_date  hardship_end_date  \
# 0            NaN              NaN                  NaN                NaN
# 1            NaN              NaN                  NaN                NaN
#
#    payment_plan_start_date  hardship_length  hardship_dpd  \
# 0                      NaN              NaN           NaN
# 1                      NaN              NaN           NaN
#
#    hardship_loan_status  orig_projected_additional_accrued_interest  \
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
#
#    hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
#
#    disbursement_method  debt_settlement_flag  debt_settlement_flag_date  \
# 0                 Cash                     N                        NaN
# 1                 Cash                     N                        NaN
#
#    settlement_status  settlement_date  settlement_amount  \
# 0                NaN              NaN                NaN
# 1                NaN              NaN                NaN
#
#    settlement_percentage  settlement_term
# 0                    NaN              NaN
# 1                    NaN              NaN
#
# [2 rows x 145 columns]

# %%
df2014.head(2)
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    15000.0      15000.0          15000.0   60 months
# 1  NaN        NaN    10400.0      10400.0          10400.0   36 months
#
#   int_rate  installment grade sub_grade                       emp_title  \
# 0   12.39%       336.64     C        C1                      MANAGEMENT
# 1    6.99%       321.08     A        A3  Truck Driver Delivery Personel
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0  10+ years           RENT     78000.0     Source Verified  Dec-2014
# 1    8 years       MORTGAGE     58000.0        Not Verified  Dec-2014
#
#    loan_status pymnt_plan  url desc             purpose  \
# 0   Fully Paid          n  NaN  NaN  debt_consolidation
# 1  Charged Off          n  NaN  NaN         credit_card
#
#                      title zip_code addr_state    dti  delinq_2yrs  \
# 0       Debt consolidation    235xx         VA  12.03          0.0
# 1  Credit card refinancing    937xx         CA  14.92          0.0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0         Aug-1994             0.0                     NaN
# 1         Sep-1989             2.0                    42.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN       6.0      0.0   138008.0        29%       17.0
# 1                     NaN      17.0      0.0     6133.0      31.6%       36.0
#
#   initial_list_status  out_prncp       ...         total_bal_ex_mort  \
# 0                   w        0.0       ...                  149140.0
# 1                   w        0.0       ...                   15030.0
#
#    total_bc_limit  total_il_high_credit_limit  revol_bal_joint  \
# 0         10000.0                     12000.0              NaN
# 1         13000.0                     11325.0              NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                       NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
#
#    sec_app_open_acc sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                NaN                  NaN
# 1               NaN                NaN                  NaN
#
#   sec_app_num_rev_accts sec_app_chargeoff_within_12_mths  \
# 0                   NaN                              NaN
# 1                   NaN                              NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
#
#    hardship_flag hardship_type  hardship_reason  hardship_status  \
# 0              N           NaN              NaN              NaN
# 1              N           NaN              NaN              NaN
#
#    deferral_term  hardship_amount  hardship_start_date  hardship_end_date  \
# 0            NaN              NaN                  NaN                NaN
# 1            NaN              NaN                  NaN                NaN
#
#    payment_plan_start_date  hardship_length  hardship_dpd  \
# 0                      NaN              NaN           NaN
# 1                      NaN              NaN           NaN
#
#    hardship_loan_status  orig_projected_additional_accrued_interest  \
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
#
#    hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
#
#    disbursement_method  debt_settlement_flag  debt_settlement_flag_date  \
# 0                 Cash                     N                        NaN
# 1                 Cash                     N                        NaN
#
#    settlement_status  settlement_date  settlement_amount  \
# 0                NaN              NaN                NaN
# 1                NaN              NaN                NaN
#
#    settlement_percentage  settlement_term
# 0                    NaN              NaN
# 1                    NaN              NaN
#
# [2 rows x 145 columns]

# %% [markdown]
# ## Clean data

# %%
# Merge datasets

data = pd.concat([df2012_13,df2014])
data.shape
# Out:
# (423814, 145)

# %%
data.isnull().sum()
# Out:
# id                                            423810
# member_id                                     423814
# loan_amnt                                          4
# funded_amnt                                        4
# funded_amnt_inv                                    4
# term                                               4
# int_rate                                           4
# installment                                        4
# grade                                              4
# sub_grade                                          4
# emp_title                                      24974
# emp_length                                         4
# home_ownership                                     4
# annual_inc                                         4
# verification_status                                4
# issue_d                                            4
# loan_status                                        4
# pymnt_plan                                         4
# url                                           423814
# desc                                          327057
# purpose                                            4
# title                                             11
# zip_code                                           4
# addr_state                                         4
# dti                                                4
# delinq_2yrs                                        4
# earliest_cr_line                                   4
# inq_last_6mths                                     4
# mths_since_last_delinq                        223458
# mths_since_last_record                        364816
#                                                ...
# sec_app_open_acc                              423814
# sec_app_revol_util                            423814
# sec_app_open_act_il                           423814
# sec_app_num_rev_accts                         423814
# sec_app_chargeoff_within_12_mths              423814
# sec_app_collections_12_mths_ex_med            423814
# sec_app_mths_since_last_major_derog           423814
# hardship_flag                                      4
# hardship_type                                 423235
# hardship_reason                               423235
# hardship_status                               423235
# deferral_term                                 423235
# hardship_amount                               423235
# hardship_start_date                           423235
# hardship_end_date                             423235
# payment_plan_start_date                       423235
# hardship_length                               423235
# hardship_dpd                                  423235
# hardship_loan_status                          423235
# orig_projected_additional_accrued_interest    423347
# hardship_payoff_balance_amount                423235
# hardship_last_payment_amount                  423235
# disbursement_method                                4
# debt_settlement_flag                               4
# debt_settlement_flag_date                     417576
# settlement_status                             417576
# settlement_date                               417576
# settlement_amount                             417576
# settlement_percentage                         417576
# settlement_term                               417576
# dtype: int64

# %%
data.dropna(axis=1,how='all', inplace=True)
data.shape
# Out:
# (423814, 115)

# %%
data['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Late (16-30 days)',
#        'Late (31-120 days)', 'Current', 'In Grace Period', nan], dtype=object)

# %%
data = data[(data['loan_status']=="Fully Paid") | (data['loan_status']=="Charged Off")]
data.shape
# Out:
# MemoryErrorTraceback (most recent call last)
# <ipython-input-23-7d5683b19e25> in <module>()
# ----> 1 data = data[(data['loan_status']=="Fully Paid") | (data['loan_status']=="Charged Off")]
#       2 data.shape
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2093             key = check_bool_indexer(self.index, key)
#    2094             indexer = key.nonzero()[0]
# -> 2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
#    2097             indexer = self.ix._convert_to_indexer(key, axis=1)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in take(self, indices, axis, convert, is_copy, **kwargs)
#    1667         new_data = self._data.take(indices,
#    1668                                    axis=self._get_block_manager_axis(axis),
# -> 1669                                    convert=True, verify=True)
#    1670         result = self._constructor(new_data).__finalize__(self)
#    1671
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in take(self, indexer, axis, verify, convert)
#    3962         new_labels = self.axes[axis].take(indexer)
#    3963         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 3964                                     axis=axis, allow_dups=True)
#    3965
#    3966     def merge(self, other, lsuffix='', rsuffix=''):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3848             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    3849                 fill_value if fill_value is not None else blk.fill_value,))
# -> 3850                 for blk in self.blocks]
#    3851
#    3852         new_axes = list(self.axes)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    3848             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    3849                 fill_value if fill_value is not None else blk.fill_value,))
# -> 3850                 for blk in self.blocks]
#    3851
#    3852         new_axes = list(self.axes)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1020             fill_value = fill_tuple[0]
#    1021             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1022                                        allow_fill=True, fill_value=fill_value)
#    1023
#    1024         if new_mgr_locs is None:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1098             out = np.empty(out_shape, dtype=dtype, order='F')
#    1099         else:
# -> 1100             out = np.empty(out_shape, dtype=dtype)
#    1101
#    1102     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#
# MemoryError:
